# %% [markdown]
# <a href="https://colab.research.google.com/github/paolagabriel/TESTE/blob/main/projetos1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **trabalho 1 sobre python**
#
#
# 1. trabalho numero
# 2. numero é par ou impar

# %%
numero = int(input("Digite o numero!"))
if numero %2==0:
  print("O numero é par")
else:
  print("o numero é impar")
# Out:
# Digite o numero!3
# o numero é impar
